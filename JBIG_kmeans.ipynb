# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import seaborn as sns

# %%
test = pd.read_csv("C:/Users/user/Desktop/test.csv")

# %%
test = test.drop('name', axis =1)

# %%
kmeans = KMeans(n_clusters=6, random_state=2)

# %%
test_cl = kmeans.fit(test)

# %%
result = test.copy()
result["cluster"] = test_cl.labels_
result
# Out:
#     q1  q2  q3  q4  q5  q6  q7  q8  q9  q10  q11  cluster
# 0    3   4   7   9   6   5   8   7   7    2    5        0
# 1    6   2  10   8   2   4   4   1   3    5    9        3
# 2    5   9   1   7   5   9   8   1  10    2    1        1
# 3    4   9   1   6   9   2   1  10   3    1    9        4
# 4    7   8   6   8   6   4   6   4   2    1    4        1
# 5    7   7   4   4   9  10   4   2   7    1    9        2
# 6    7   4   3   9   5   9  10   5   2    6    9        2
# 7    5  10   1   4  10   9   6   9   3    4    6        4
# 8    8  10   1   7   1   7   9  10   5    2    3        1
# 9   10   1   7   8  10   3   6  10   9    8    3        0
# 10   1   3   1   2   3   7   7   4   5    8    7        2
# 11  10   4   5   6   8   6   6  10   6    8    4        0
# 12   7   4   3   8   7   3   2   8   8    3    2        0
# 13   8   1   2  10   2   8   2   8   1   10    2        0
# 14   2   2   4   1   3  10   7   5   6    6    9        2
# 15   7   9   7   1   2   3   5   3   2    4    5        1
# 16   1   2   9   9   6   3   8  10   4    6    2        0
# 17   2   7   6  10   1   4   3   5   7    5    9        5
# 18   8   4   2   1   5   9  10   2   6    6    9        2
# 19   8   5   7   9   6   1   9   6   3    3    7        1
# 20   8   2   6   6   1   5  10   3   4    2    2        1
# 21   2   5  10   8   4  10   3   6   7    8    4        5
# 22  10   9   6   4  10   4   5   6   1    4    8        4
# 23   4   6   9   2  10   2   6   1   1    6    7        3
# 24   6  10   5   9   4   2   2   3   1    9   10        5
# 25   5   8   3   6   2   9   4   8   1    7    2        1
# 26   5  10   8   2   2   3   7   4   7    3    6        1
# 27   4   5   4   8   3   8   3   7  10    2    4        5
# 28   3   2   9   3   8   3   6   2   2    3    5        3
# 29   6   2   6   5   4   7   3   3   4    3    6        3

# %%
pca = PCA(n_components=5)

# %%
pca_test = pca.fit_transform(test)

# %%
pcaDf = pd.DataFrame(data=pca_test, columns = ['comp1', 'comp2','comp3','comp4','comp5'])
pcaDf['cluster'] = result['cluster']

# %%
sns.scatterplot(x="comp1", y="comp2", hue="cluster", data=pcaDf, palette="Set2")
# Out:
# <AxesSubplot:xlabel='comp1', ylabel='comp2'>
